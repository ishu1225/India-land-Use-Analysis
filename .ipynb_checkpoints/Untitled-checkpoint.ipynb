# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('data.csv')  # Replace with your file path

# Print column names and sample data
print("Available Columns in Dataset:\n", df.columns.tolist())
print("\nFirst few rows:\n", df.head())
# Out:
# Available Columns in Dataset:
#  ['ROWID', 'Country', 'State lgd code', 'State', 'District lgd code', 'District', 'YearCode', 'Year', 'Reported land area ', 'Forest land area', 'Land area under non-agricultural uses', 'Barren and unculturable land area', 'Permanent pasture and other grazing land area', 'Land under miscellaneous Tree Crops and Groves not included in Net Area Sown', 'Culturable waste land area', 'Fallow lands other than current fallow lands', 'Current Fallow land area', 'Net sown land area', 'Cropped land area', 'Land area sown more than once']
#
# First few rows:
#     ROWID Country  State lgd code              State  District lgd code  \
# 0      1   India               1  Jammu And Kashmir                  1
# 1      2   India               1  Jammu And Kashmir                  1
# 2      3   India               1  Jammu And Kashmir                  1
# 3      4   India               1  Jammu And Kashmir                  1
# 4      5   India               1  Jammu And Kashmir                  1
#
#    District  YearCode                                Year  \
# 0  Anantnag      2011  Agriculture Year (Jul - Jun), 2011
# 1  Anantnag      2012  Agriculture Year (Jul - Jun), 2012
# 2  Anantnag      2013  Agriculture Year (Jul - Jun), 2013
# 3  Anantnag      2014  Agriculture Year (Jul - Jun), 2014
# 4  Anantnag      2015  Agriculture Year (Jul - Jun), 2015
#
#    Reported land area   Forest land area  \
# 0              72149.0             288.0
# 1              72149.0             253.0
# 2              72149.0             253.0
# 3              72149.0             253.0
# 4              72149.0             253.0
#
#    Land area under non-agricultural uses  Barren and unculturable land area  \
# 0                                 5878.0                             6604.0
# 1                                 5878.0                             6129.0
# 2                                 5878.0                             6129.0
# 3                                 5878.0                             6129.0
# 4                                 5878.0                             6129.0
#
#    Permanent pasture and other grazing land area  \
# 0                                         6905.0
# 1                                         6905.0
# 2                                         6905.0
# 3                                         6983.0
# 4                                         6983.0
#
#    Land under miscellaneous Tree Crops and Groves not included in Net Area Sown  \
# 0                                             2093.0
# 1                                             2093.0
# 2                                             2093.0
# 3                                             2020.0
# 4                                             2092.0
#
#    Culturable waste land area  Fallow lands other than current fallow lands  \
# 0                      2520.0                                           0.0
# 1                      2768.0                                         262.0
# 2                      2768.0                                         262.0
# 3                      2768.0                                         287.0
# 4                      3049.0                                        2460.0
#
#    Current Fallow land area  Net sown land area  Cropped land area  \
# 0                       0.0             47861.0            71432.0
# 1                       0.0             47861.0            71432.0
# 2                       0.0             47861.0            71520.0
# 3                     602.0             47229.0            70955.0
# 4                    9882.0             35423.0            58830.0
#
#    Land area sown more than once
# 0                        23571.0
# 1                        23571.0
# 2                        23659.0
# 3                        23726.0
# 4                        23407.0

# %%
# Cleaning the dataset 
# Import basic libraries for cleaning
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('land_use_data.csv')  # Replace with your actual file path

# Confirm column names
print("Available Columns in Dataset:\n", df.columns.tolist())
print("\nFirst few rows:\n", df.head())

# Define numeric columns based on your dataset
numeric_cols = [
    'Reported land area ', 
    'Forest land area', 
    'Net sown land area', 
    'Cropped land area', 
    'Land area sown more than once', 
    'Barren and unculturable land area', 
    'Culturable waste land area'
]
print("\nUsing these numeric columns for analysis:", numeric_cols)

# Ensure numeric consistency
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
print("\nInitial Data Types:\n", df.dtypes)

# Check initial missing values
print("\nInitial Missing Values:\n", df.isnull().sum())

# Replace zeros with NaN
df[numeric_cols] = df[numeric_cols].replace(0, np.nan)
print("\nMissing Values After Replacing Zeros:\n", df.isnull().sum())

# Fill missing values with column means
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
print("\nMissing Values After Imputation:\n", df.isnull().sum())

# Assign cleaned DataFrame
df_clean = df
print(f"\nRows after cleaning: {df_clean.shape[0]}")
# Out:
# Available Columns in Dataset:
#  ['ROWID', 'Country', 'State lgd code', 'State', 'District lgd code', 'District', 'YearCode', 'Year', 'Reported land area ', 'Forest land area', 'Land area under non-agricultural uses', 'Barren and unculturable land area', 'Permanent pasture and other grazing land area', 'Land under miscellaneous Tree Crops and Groves not included in Net Area Sown', 'Culturable waste land area', 'Fallow lands other than current fallow lands', 'Current Fallow land area', 'Net sown land area', 'Cropped land area', 'Land area sown more than once']
#
# First few rows:
#     ROWID Country  State lgd code              State  District lgd code  \
# 0      1   India               1  Jammu And Kashmir                  1
# 1      2   India               1  Jammu And Kashmir                  1
# 2      3   India               1  Jammu And Kashmir                  1
# 3      4   India               1  Jammu And Kashmir                  1
# 4      5   India               1  Jammu And Kashmir                  1
#
#    District  YearCode                                Year  \
# 0  Anantnag      2011  Agriculture Year (Jul - Jun), 2011
# 1  Anantnag      2012  Agriculture Year (Jul - Jun), 2012
# 2  Anantnag      2013  Agriculture Year (Jul - Jun), 2013
# 3  Anantnag      2014  Agriculture Year (Jul - Jun), 2014
# 4  Anantnag      2015  Agriculture Year (Jul - Jun), 2015
#
#    Reported land area   Forest land area  \
# 0              72149.0             288.0
# 1              72149.0             253.0
# 2              72149.0             253.0
# 3              72149.0             253.0
# 4              72149.0             253.0
#
#    Land area under non-agricultural uses  Barren and unculturable land area  \
# 0                                 5878.0                             6604.0
# 1                                 5878.0                             6129.0
# 2                                 5878.0                             6129.0
# 3                                 5878.0                             6129.0
# 4                                 5878.0                             6129.0
#
#    Permanent pasture and other grazing land area  \
# 0                                         6905.0
# 1                                         6905.0
# 2                                         6905.0
# 3                                         6983.0
# 4                                         6983.0
#
#    Land under miscellaneous Tree Crops and Groves not included in Net Area Sown  \
# 0                                             2093.0
# 1                                             2093.0
# 2                                             2093.0
# 3                                             2020.0
# 4                                             2092.0
#
#    Culturable waste land area  Fallow lands other than current fallow lands  \
# 0                      2520.0                                           0.0
# 1                      2768.0                                         262.0
# 2                      2768.0                                         262.0
# 3                      2768.0                                         287.0
# 4                      3049.0                                        2460.0
#
#    Current Fallow land area  Net sown land area  Cropped land area  \
# 0                       0.0             47861.0            71432.0
# 1                       0.0             47861.0            71432.0
# 2                       0.0             47861.0            71520.0
# 3                     602.0             47229.0            70955.0
# 4                    9882.0             35423.0            58830.0
#
#    Land area sown more than once
# 0                        23571.0
# 1                        23571.0
# 2                        23659.0
# 3                        23726.0
# 4                        23407.0
#
# Using these numeric columns for analysis: ['Reported land area ', 'Forest land area', 'Net sown land area', 'Cropped land area', 'Land area sown more than once', 'Barren and unculturable land area', 'Culturable waste land area']
#
# Initial Data Types:
#  ROWID                                                                             int64
# Country                                                                          object
# State lgd code                                                                    int64
# State                                                                            object
# District lgd code                                                                 int64
# District                                                                         object
# YearCode                                                                          int64
# Year                                                                             object
# Reported land area                                                              float64
# Forest land area                                                                float64
# Land area under non-agricultural uses                                           float64
# Barren and unculturable land area                                               float64
# Permanent pasture and other grazing land area                                   float64
# Land under miscellaneous Tree Crops and Groves not included in Net Area Sown    float64
# Culturable waste land area                                                      float64
# Fallow lands other than current fallow lands                                    float64
# Current Fallow land area                                                        float64
# Net sown land area                                                              float64
# Cropped land area                                                               float64
# Land area sown more than once                                                   float64
# dtype: object
#
# Initial Missing Values:
#  ROWID                                                                             0
# Country                                                                           0
# State lgd code                                                                    0
# State                                                                             0
# District lgd code                                                                 0
# District                                                                          0
# YearCode                                                                          0
# Year                                                                              0
# Reported land area                                                              208
# Forest land area                                                                208
# Land area under non-agricultural uses                                           208
# Barren and unculturable land area                                               208
# Permanent pasture and other grazing land area                                   208
# Land under miscellaneous Tree Crops and Groves not included in Net Area Sown    208
# Culturable waste land area                                                      208
# Fallow lands other than current fallow lands                                    208
# Current Fallow land area                                                        208
# Net sown land area                                                              208
# Cropped land area                                                               208
# Land area sown more than once                                                   208
# dtype: int64
#
# Missing Values After Replacing Zeros:
#  ROWID                                                                             0
# Country                                                                           0
# State lgd code                                                                    0
# State                                                                             0
# District lgd code                                                                 0
# District                                                                          0
# YearCode                                                                          0
# Year                                                                              0
# Reported land area                                                              208
# Forest land area                                                                633
# Land area under non-agricultural uses                                           208
# Barren and unculturable land area                                               438
# Permanent pasture and other grazing land area                                   208
# Land under miscellaneous Tree Crops and Groves not included in Net Area Sown    208
# Culturable waste land area                                                      576
# Fallow lands other than current fallow lands                                    208
# Current Fallow land area                                                        208
# Net sown land area                                                              216
# Cropped land area                                                               216
# Land area sown more than once                                                   254
# dtype: int64
#
# Missing Values After Imputation:
#  ROWID                                                                             0
# Country                                                                           0
# State lgd code                                                                    0
# State                                                                             0
# District lgd code                                                                 0
# District                                                                          0
# YearCode                                                                          0
# Year                                                                              0
# Reported land area                                                                0
# Forest land area                                                                  0
# Land area under non-agricultural uses                                           208
# Barren and unculturable land area                                                 0
# Permanent pasture and other grazing land area                                   208
# Land under miscellaneous Tree Crops and Groves not included in Net Area Sown    208
# Culturable waste land area                                                        0
# Fallow lands other than current fallow lands                                    208
# Current Fallow land area                                                        208
# Net sown land area                                                                0
# Cropped land area                                                                 0
# Land area sown more than once                                                     0
# dtype: int64
#
# Rows after cleaning: 5786
